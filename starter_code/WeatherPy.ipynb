# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/salitasantiago/opt/anaconda3/envs/PythonData1/lib/python3.6/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/salitasantiago/opt/anaconda3/envs/PythonData1/lib/python3.6/site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 597

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
count = 1

# instantiate the lists to hold the data for each city
city_list = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

for city in cities:    
        # assemble url and make API request
        print(f"Processing Record {count} of Set 1 | {city}.")
        count = count + 1
        
        target_url = ("http://api.openweathermap.org/data/2.5/weather?"
                      'appid={0}&q={1}').format(weather_api_key,city)
        try:
            # extract results
            response = requests.get(target_url).json()
            
            # add the city info to the lists             
            city_list.append(response['name'])
            cloudiness.append(response['clouds']['all'])
            country.append(response['sys']['country'])
            date.append(response['dt'])
            humidity.append(response['main']['humidity'])
            lat.append(response['coord']['lat'])
            lng.append(response['coord']['lon'])
            max_temp.append(response['main']['temp_max'])
            wind_speed.append(response['wind']['speed'])
            
        except:
            print("City not found. Skipping...")
# Out:
# Processing Record 1 of Set 1 | gamba.
# Processing Record 2 of Set 1 | kavieng.
# Processing Record 3 of Set 1 | bredasdorp.
# Processing Record 4 of Set 1 | longyearbyen.
# Processing Record 5 of Set 1 | dayong.
# Processing Record 6 of Set 1 | hobart.
# Processing Record 7 of Set 1 | binga.
# Processing Record 8 of Set 1 | vaini.
# Processing Record 9 of Set 1 | mahadday weyne.
# City not found. Skipping...
# Processing Record 10 of Set 1 | hithadhoo.
# Processing Record 11 of Set 1 | thompson.
# Processing Record 12 of Set 1 | touros.
# Processing Record 13 of Set 1 | kyzyl-suu.
# Processing Record 14 of Set 1 | nizhneyansk.
# City not found. Skipping...
# Processing Record 15 of Set 1 | kushima.
# Processing Record 16 of Set 1 | mar del plata.
# Processing Record 17 of Set 1 | mabaruma.
# Processing Record 18 of Set 1 | amderma.
# City not found. Skipping...
# Processing Record 19 of Set 1 | avarua.
# Processing Record 20 of Set 1 | narsaq.
# Processing Record 21 of Set 1 | punta arenas.
# Processing Record 22 of Set 1 | shenzhen.
# Processing Record 23 of Set 1 | bosobolo.
# Processing Record 24 of Set 1 | hamilton.
# Processing Record 25 of Set 1 | magadan.
# Processing Record 26 of Set 1 | barentsburg.
# City not found. Skipping...
# Processing Record 27 of Set 1 | alice.
# Processing Record 28 of Set 1 | bengkulu.
# Processing Record 29 of Set 1 | college.
# Processing Record 30 of Set 1 | grand river south east.
# City not found. Skipping...
# Processing Record 31 of Set 1 | castro.
# Processing Record 32 of Set 1 | tasiilaq.
# Processing Record 33 of Set 1 | kyren.
# Processing Record 34 of Set 1 | ushuaia.
# Processing Record 35 of Set 1 | albany.
# Processing Record 36 of Set 1 | butaritari.
# Processing Record 37 of Set 1 | tabiauea.
# City not found. Skipping...
# Processing Record 38 of Set 1 | jamestown.
# Processing Record 39 of Set 1 | tuktoyaktuk.
# Processing Record 40 of Set 1 | lipari.
# Processing Record 41 of Set 1 | yar-sale.
# Processing Record 42 of Set 1 | sentyabrskiy.
# City not found. Skipping...
# Processing Record 43 of Set 1 | anadyr.
# Processing Record 44 of Set 1 | qunduz.
# Processing Record 45 of Set 1 | misratah.
# Processing Record 46 of Set 1 | cape town.
# Processing Record 47 of Set 1 | saint-philippe.
# Processing Record 48 of Set 1 | madimba.
# Processing Record 49 of Set 1 | san patricio.
# Processing Record 50 of Set 1 | east london.
# Processing Record 51 of Set 1 | nekhayevskiy.
# Processing Record 52 of Set 1 | yerofey pavlovich.
# Processing Record 53 of Set 1 | upernavik.
# Processing Record 54 of Set 1 | rikitea.
# Processing Record 55 of Set 1 | taolanaro.
# City not found. Skipping...
# Processing Record 56 of Set 1 | busselton.
# Processing Record 57 of Set 1 | hermanus.
# Processing Record 58 of Set 1 | cayenne.
# Processing Record 59 of Set 1 | torbay.
# Processing Record 60 of Set 1 | alice springs.
# Processing Record 61 of Set 1 | te anau.
# Processing Record 62 of Set 1 | lamar.
# Processing Record 63 of Set 1 | karratha.
# Processing Record 64 of Set 1 | illoqqortoormiut.
# City not found. Skipping...
# Processing Record 65 of Set 1 | barrow.
# Processing Record 66 of Set 1 | rabo de peixe.
# Processing Record 67 of Set 1 | shache.
# Processing Record 68 of Set 1 | obidos.
# Processing Record 69 of Set 1 | faanui.
# Processing Record 70 of Set 1 | kiunga.
# Processing Record 71 of Set 1 | dikson.
# Processing Record 72 of Set 1 | broome.
# Processing Record 73 of Set 1 | clyde river.
# Processing Record 74 of Set 1 | jining.
# Processing Record 75 of Set 1 | inhambane.
# Processing Record 76 of Set 1 | marsh harbour.
# Processing Record 77 of Set 1 | hilo.
# Processing Record 78 of Set 1 | ilulissat.
# Processing Record 79 of Set 1 | grindavik.
# Processing Record 80 of Set 1 | raudeberg.
# Processing Record 81 of Set 1 | haines junction.
# Processing Record 82 of Set 1 | waingapu.
# Processing Record 83 of Set 1 | pangnirtung.
# Processing Record 84 of Set 1 | maumere.
# Processing Record 85 of Set 1 | eureka.
# Processing Record 86 of Set 1 | saldanha.
# Processing Record 87 of Set 1 | yellowknife.
# Processing Record 88 of Set 1 | mehran.
# Processing Record 89 of Set 1 | bluff.
# Processing Record 90 of Set 1 | agadez.
# Processing Record 91 of Set 1 | kruisfontein.
# Processing Record 92 of Set 1 | port alfred.
# Processing Record 93 of Set 1 | khatanga.
# Processing Record 94 of Set 1 | nishihara.
# Processing Record 95 of Set 1 | muscatine.
# Processing Record 96 of Set 1 | ruatoria.
# City not found. Skipping...
# Processing Record 97 of Set 1 | wenling.
# Processing Record 98 of Set 1 | mataura.
# Processing Record 99 of Set 1 | dali.
# Processing Record 100 of Set 1 | sitka.
# Processing Record 101 of Set 1 | attawapiskat.
# City not found. Skipping...
# Processing Record 102 of Set 1 | katangli.
# Processing Record 103 of Set 1 | atuona.
# Processing Record 104 of Set 1 | loei.
# Processing Record 105 of Set 1 | opalenica.
# Processing Record 106 of Set 1 | victoria.
# Processing Record 107 of Set 1 | myitkyina.
# Processing Record 108 of Set 1 | ketchikan.
# Processing Record 109 of Set 1 | richards bay.
# Processing Record 110 of Set 1 | tilichiki.
# Processing Record 111 of Set 1 | sao joao da barra.
# Processing Record 112 of Set 1 | sao felix do xingu.
# Processing Record 113 of Set 1 | karamken.
# City not found. Skipping...
# Processing Record 114 of Set 1 | hambantota.
# Processing Record 115 of Set 1 | vaitupu.
# City not found. Skipping...
# Processing Record 116 of Set 1 | lorengau.
# Processing Record 117 of Set 1 | port elizabeth.
# Processing Record 118 of Set 1 | qaanaaq.
# Processing Record 119 of Set 1 | lata.
# Processing Record 120 of Set 1 | talavera de la reina.
# Processing Record 121 of Set 1 | mys shmidta.
# City not found. Skipping...
# Processing Record 122 of Set 1 | catio.
# Processing Record 123 of Set 1 | sao filipe.
# Processing Record 124 of Set 1 | salalah.
# Processing Record 125 of Set 1 | provideniya.
# Processing Record 126 of Set 1 | tubruq.
# City not found. Skipping...
# Processing Record 127 of Set 1 | kodiak.
# Processing Record 128 of Set 1 | bambous virieux.
# Processing Record 129 of Set 1 | kapaa.
# Processing Record 130 of Set 1 | lakes entrance.
# Processing Record 131 of Set 1 | colares.
# Processing Record 132 of Set 1 | gilgit.
# Processing Record 133 of Set 1 | altay.
# Processing Record 134 of Set 1 | padang.
# Processing Record 135 of Set 1 | port-gentil.
# Processing Record 136 of Set 1 | codrington.
# Processing Record 137 of Set 1 | coihaique.
# Processing Record 138 of Set 1 | aporawan.
# City not found. Skipping...
# Processing Record 139 of Set 1 | natal.
# Processing Record 140 of Set 1 | kulhudhuffushi.
# Processing Record 141 of Set 1 | mahuva.
# Processing Record 142 of Set 1 | mweka.
# Processing Record 143 of Set 1 | pahrump.
# Processing Record 144 of Set 1 | hofn.
# Processing Record 145 of Set 1 | erenhot.
# Processing Record 146 of Set 1 | carnarvon.
# Processing Record 147 of Set 1 | namibe.
# Processing Record 148 of Set 1 | lebu.
# Processing Record 149 of Set 1 | kehtna.
# Processing Record 150 of Set 1 | nanticoke.
# Processing Record 151 of Set 1 | todos santos.
# Processing Record 152 of Set 1 | belushya guba.
# City not found. Skipping...
# Processing Record 153 of Set 1 | kaitangata.
# Processing Record 154 of Set 1 | georgetown.
# Processing Record 155 of Set 1 | kasongo-lunda.
# Processing Record 156 of Set 1 | acarau.
# Processing Record 157 of Set 1 | mahebourg.
# Processing Record 158 of Set 1 | saskylakh.
# Processing Record 159 of Set 1 | grants pass.
# Processing Record 160 of Set 1 | pevek.
# Processing Record 161 of Set 1 | mana.
# Processing Record 162 of Set 1 | lavrentiya.
# Processing Record 163 of Set 1 | clarence town.
# Processing Record 164 of Set 1 | biga.
# Processing Record 165 of Set 1 | acatlan.
# Processing Record 166 of Set 1 | sur.
# Processing Record 167 of Set 1 | grand gaube.
# Processing Record 168 of Set 1 | brooks.
# Processing Record 169 of Set 1 | bethel.
# Processing Record 170 of Set 1 | gat.
# Processing Record 171 of Set 1 | fort atkinson.
# Processing Record 172 of Set 1 | takestan.
# Processing Record 173 of Set 1 | russell.
# Processing Record 174 of Set 1 | new norfolk.
# Processing Record 175 of Set 1 | bilma.
# Processing Record 176 of Set 1 | ahuimanu.
# Processing Record 177 of Set 1 | deseronto.
# Processing Record 178 of Set 1 | bentiu.
# Processing Record 179 of Set 1 | faya.
# Processing Record 180 of Set 1 | saint anthony.
# Processing Record 181 of Set 1 | evensk.
# Processing Record 182 of Set 1 | nikolskoye.
# Processing Record 183 of Set 1 | cabo san lucas.
# Processing Record 184 of Set 1 | dzhebariki-khaya.
# Processing Record 185 of Set 1 | merrill.
# Processing Record 186 of Set 1 | sao jose da coroa grande.
# Processing Record 187 of Set 1 | guaira.
# Processing Record 188 of Set 1 | pemba.
# Processing Record 189 of Set 1 | isangel.
# Processing Record 190 of Set 1 | breves.
# Processing Record 191 of Set 1 | souillac.
# Processing Record 192 of Set 1 | shu.
# Processing Record 193 of Set 1 | bytosh.
# Processing Record 194 of Set 1 | serik.
# Processing Record 195 of Set 1 | hasaki.
# Processing Record 196 of Set 1 | namatanai.
# Processing Record 197 of Set 1 | panjakent.
# Processing Record 198 of Set 1 | myaundzha.
# Processing Record 199 of Set 1 | tezu.
# Processing Record 200 of Set 1 | bandar.
# Processing Record 201 of Set 1 | sfantu gheorghe.
# Processing Record 202 of Set 1 | aklavik.
# Processing Record 203 of Set 1 | constitucion.
# Processing Record 204 of Set 1 | tottori.
# Processing Record 205 of Set 1 | havoysund.
# Processing Record 206 of Set 1 | raga.
# Processing Record 207 of Set 1 | ndele.
# Processing Record 208 of Set 1 | naze.
# Processing Record 209 of Set 1 | cidreira.
# Processing Record 210 of Set 1 | sibolga.
# Processing Record 211 of Set 1 | puerto ayora.
# Processing Record 212 of Set 1 | otane.
# Processing Record 213 of Set 1 | tsihombe.
# City not found. Skipping...
# Processing Record 214 of Set 1 | port hedland.
# Processing Record 215 of Set 1 | mackay.
# Processing Record 216 of Set 1 | vao.
# Processing Record 217 of Set 1 | comodoro rivadavia.
# Processing Record 218 of Set 1 | nyurba.
# Processing Record 219 of Set 1 | mount gambier.
# Processing Record 220 of Set 1 | lichuan.
# Processing Record 221 of Set 1 | astoria.
# Processing Record 222 of Set 1 | hoi an.
# Processing Record 223 of Set 1 | kerugoya.
# Processing Record 224 of Set 1 | chokurdakh.
# Processing Record 225 of Set 1 | santa cruz cabralia.
# Processing Record 226 of Set 1 | manokwari.
# Processing Record 227 of Set 1 | jalu.
# Processing Record 228 of Set 1 | ancud.
# Processing Record 229 of Set 1 | qaqortoq.
# Processing Record 230 of Set 1 | pisco.
# Processing Record 231 of Set 1 | itaituba.
# Processing Record 232 of Set 1 | bend.
# Processing Record 233 of Set 1 | skjervoy.
# Processing Record 234 of Set 1 | ribeira grande.
# Processing Record 235 of Set 1 | nanortalik.
# Processing Record 236 of Set 1 | tiksi.
# Processing Record 237 of Set 1 | nhulunbuy.
# Processing Record 238 of Set 1 | saleaula.
# City not found. Skipping...
# Processing Record 239 of Set 1 | black diamond.
# Processing Record 240 of Set 1 | solothurn.
# Processing Record 241 of Set 1 | farmington.
# Processing Record 242 of Set 1 | komsomolskiy.
# Processing Record 243 of Set 1 | quartucciu.
# Processing Record 244 of Set 1 | lerwick.
# Processing Record 245 of Set 1 | keetmanshoop.
# Processing Record 246 of Set 1 | fortuna.
# Processing Record 247 of Set 1 | yinchuan.
# Processing Record 248 of Set 1 | san cristobal.
# Processing Record 249 of Set 1 | hualmay.
# Processing Record 250 of Set 1 | ziyamet.
# City not found. Skipping...
# Processing Record 251 of Set 1 | kudahuvadhoo.
# Processing Record 252 of Set 1 | marystown.
# Processing Record 253 of Set 1 | sturgis.
# Processing Record 254 of Set 1 | karaul.
# City not found. Skipping...
# Processing Record 255 of Set 1 | dingle.
# Processing Record 256 of Set 1 | porto belo.
# Processing Record 257 of Set 1 | manggar.
# Processing Record 258 of Set 1 | bonfim.
# Processing Record 259 of Set 1 | norman wells.
# Processing Record 260 of Set 1 | palmer.
# Processing Record 261 of Set 1 | sindor.
# Processing Record 262 of Set 1 | bilibino.
# Processing Record 263 of Set 1 | ahipara.
# Processing Record 264 of Set 1 | adrar.
# Processing Record 265 of Set 1 | ust-nera.
# Processing Record 266 of Set 1 | katsuura.
# Processing Record 267 of Set 1 | najran.
# Processing Record 268 of Set 1 | alofi.
# Processing Record 269 of Set 1 | matara.
# Processing Record 270 of Set 1 | deputatskiy.
# Processing Record 271 of Set 1 | mandalgovi.
# Processing Record 272 of Set 1 | ponta do sol.
# Processing Record 273 of Set 1 | grimari.
# City not found. Skipping...
# Processing Record 274 of Set 1 | acapulco.
# Processing Record 275 of Set 1 | alappuzha.
# Processing Record 276 of Set 1 | geraldton.
# Processing Record 277 of Set 1 | san policarpo.
# Processing Record 278 of Set 1 | quatre cocos.
# Processing Record 279 of Set 1 | mazara del vallo.
# Processing Record 280 of Set 1 | gazanjyk.
# Processing Record 281 of Set 1 | agra.
# Processing Record 282 of Set 1 | saint-augustin.
# Processing Record 283 of Set 1 | halalo.
# City not found. Skipping...
# Processing Record 284 of Set 1 | riyadh.
# Processing Record 285 of Set 1 | kutum.
# Processing Record 286 of Set 1 | san jose.
# Processing Record 287 of Set 1 | nantucket.
# Processing Record 288 of Set 1 | mandi bahauddin.
# Processing Record 289 of Set 1 | sayyan.
# Processing Record 290 of Set 1 | waverly.
# Processing Record 291 of Set 1 | nyrob.
# Processing Record 292 of Set 1 | nago.
# Processing Record 293 of Set 1 | dickinson.
# Processing Record 294 of Set 1 | tevaitoa.
# Processing Record 295 of Set 1 | payo.
# Processing Record 296 of Set 1 | pavlohrad.
# Processing Record 297 of Set 1 | kananga.
# Processing Record 298 of Set 1 | carauari.
# Processing Record 299 of Set 1 | borama.
# City not found. Skipping...
# Processing Record 300 of Set 1 | umzimvubu.
# City not found. Skipping...
# Processing Record 301 of Set 1 | hibbing.
# Processing Record 302 of Set 1 | muncar.
# Processing Record 303 of Set 1 | baiyin.
# Processing Record 304 of Set 1 | vila velha.
# Processing Record 305 of Set 1 | huayucachi.
# Processing Record 306 of Set 1 | bonnyville.
# Processing Record 307 of Set 1 | kunszentmiklos.
# Processing Record 308 of Set 1 | mocuba.
# Processing Record 309 of Set 1 | wakkanai.
# Processing Record 310 of Set 1 | sumbe.
# Processing Record 311 of Set 1 | slave lake.
# Processing Record 312 of Set 1 | penzance.
# Processing Record 313 of Set 1 | husavik.
# Processing Record 314 of Set 1 | fereydun kenar.
# Processing Record 315 of Set 1 | borlange.
# City not found. Skipping...
# Processing Record 316 of Set 1 | beringovskiy.
# Processing Record 317 of Set 1 | roros.
# Processing Record 318 of Set 1 | dianopolis.
# City not found. Skipping...
# Processing Record 319 of Set 1 | pacific grove.
# Processing Record 320 of Set 1 | booue.
# Processing Record 321 of Set 1 | portland.
# Processing Record 322 of Set 1 | berdigestyakh.
# Processing Record 323 of Set 1 | arraial do cabo.
# Processing Record 324 of Set 1 | wuchang.
# Processing Record 325 of Set 1 | sa kaeo.
# Processing Record 326 of Set 1 | avera.
# Processing Record 327 of Set 1 | iskar.
# Processing Record 328 of Set 1 | sidrolandia.
# Processing Record 329 of Set 1 | sambava.
# Processing Record 330 of Set 1 | ankazoabo.
# Processing Record 331 of Set 1 | burnie.
# Processing Record 332 of Set 1 | laguna.
# Processing Record 333 of Set 1 | hami.
# Processing Record 334 of Set 1 | orotukan.
# Processing Record 335 of Set 1 | saint george.
# Processing Record 336 of Set 1 | maxixe.
# Processing Record 337 of Set 1 | nelson bay.
# Processing Record 338 of Set 1 | cabinda.
# Processing Record 339 of Set 1 | tame.
# Processing Record 340 of Set 1 | zharkent.
# Processing Record 341 of Set 1 | yirol.
# City not found. Skipping...
# Processing Record 342 of Set 1 | petropavlovsk-kamchatskiy.
# Processing Record 343 of Set 1 | taoudenni.
# Processing Record 344 of Set 1 | talnakh.
# Processing Record 345 of Set 1 | pochutla.
# Processing Record 346 of Set 1 | bolshoye sorokino.
# City not found. Skipping...
# Processing Record 347 of Set 1 | la ronge.
# Processing Record 348 of Set 1 | korla.
# Processing Record 349 of Set 1 | port lincoln.
# Processing Record 350 of Set 1 | nemuro.
# Processing Record 351 of Set 1 | garmsar.
# Processing Record 352 of Set 1 | saint-ambroise.
# Processing Record 353 of Set 1 | monroe.
# Processing Record 354 of Set 1 | bourail.
# Processing Record 355 of Set 1 | tazovskiy.
# Processing Record 356 of Set 1 | buraydah.
# Processing Record 357 of Set 1 | shieli.
# Processing Record 358 of Set 1 | okhotsk.
# Processing Record 359 of Set 1 | damavand.
# Processing Record 360 of Set 1 | rawson.
# Processing Record 361 of Set 1 | igarka.
# Processing Record 362 of Set 1 | uchaly.
# Processing Record 363 of Set 1 | srednekolymsk.
# Processing Record 364 of Set 1 | huarmey.
# Processing Record 365 of Set 1 | sinnamary.
# Processing Record 366 of Set 1 | ishigaki.
# Processing Record 367 of Set 1 | smithers.
# Processing Record 368 of Set 1 | samusu.
# City not found. Skipping...
# Processing Record 369 of Set 1 | lypova dolyna.
# Processing Record 370 of Set 1 | grand centre.
# City not found. Skipping...
# Processing Record 371 of Set 1 | redmond.
# Processing Record 372 of Set 1 | khudumelapye.
# Processing Record 373 of Set 1 | lasa.
# Processing Record 374 of Set 1 | dubti.
# Processing Record 375 of Set 1 | tutoia.
# Processing Record 376 of Set 1 | chuy.
# Processing Record 377 of Set 1 | dongsheng.
# Processing Record 378 of Set 1 | aykhal.
# Processing Record 379 of Set 1 | amapa.
# Processing Record 380 of Set 1 | los llanos de aridane.
# Processing Record 381 of Set 1 | nador.
# Processing Record 382 of Set 1 | gizo.
# Processing Record 383 of Set 1 | praia da vitoria.
# Processing Record 384 of Set 1 | puerto gaitan.
# Processing Record 385 of Set 1 | bolungarvik.
# City not found. Skipping...
# Processing Record 386 of Set 1 | beaverlodge.
# Processing Record 387 of Set 1 | okha.
# Processing Record 388 of Set 1 | kharan.
# Processing Record 389 of Set 1 | makakilo city.
# Processing Record 390 of Set 1 | lazaro cardenas.
# Processing Record 391 of Set 1 | razumnoye.
# Processing Record 392 of Set 1 | pangkalanbuun.
# Processing Record 393 of Set 1 | luderitz.
# Processing Record 394 of Set 1 | rio grande.
# Processing Record 395 of Set 1 | severo-kurilsk.
# Processing Record 396 of Set 1 | vila franca do campo.
# Processing Record 397 of Set 1 | margate.
# Processing Record 398 of Set 1 | khagrachari.
# City not found. Skipping...
# Processing Record 399 of Set 1 | alekseyevsk.
# Processing Record 400 of Set 1 | zhangjiakou.
# Processing Record 401 of Set 1 | labuhan.
# Processing Record 402 of Set 1 | sept-iles.
# Processing Record 403 of Set 1 | yining.
# Processing Record 404 of Set 1 | letlhakane.
# Processing Record 405 of Set 1 | klyuchi.
# Processing Record 406 of Set 1 | juegang.
# Processing Record 407 of Set 1 | oranjestad.
# Processing Record 408 of Set 1 | avallon.
# Processing Record 409 of Set 1 | cherskiy.
# Processing Record 410 of Set 1 | mitsamiouli.
# Processing Record 411 of Set 1 | tura.
# Processing Record 412 of Set 1 | fort nelson.
# Processing Record 413 of Set 1 | rafraf.
# Processing Record 414 of Set 1 | olafsvik.
# Processing Record 415 of Set 1 | sangar.
# Processing Record 416 of Set 1 | porto novo.
# Processing Record 417 of Set 1 | tumannyy.
# City not found. Skipping...
# Processing Record 418 of Set 1 | yanam.
# Processing Record 419 of Set 1 | dajal.
# Processing Record 420 of Set 1 | quechultenango.
# Processing Record 421 of Set 1 | tukrah.
# Processing Record 422 of Set 1 | zhanaozen.
# Processing Record 423 of Set 1 | axim.
# Processing Record 424 of Set 1 | guerrero negro.
# Processing Record 425 of Set 1 | arlit.
# Processing Record 426 of Set 1 | solnechnyy.
# Processing Record 427 of Set 1 | totness.
# Processing Record 428 of Set 1 | tateyama.
# Processing Record 429 of Set 1 | veraval.
# Processing Record 430 of Set 1 | xichang.
# Processing Record 431 of Set 1 | nguiu.
# City not found. Skipping...
# Processing Record 432 of Set 1 | dunedin.
# Processing Record 433 of Set 1 | anloga.
# Processing Record 434 of Set 1 | meadow lake.
# Processing Record 435 of Set 1 | marsa matruh.
# Processing Record 436 of Set 1 | rakiv lis.
# Processing Record 437 of Set 1 | san quintin.
# Processing Record 438 of Set 1 | airai.
# Processing Record 439 of Set 1 | merauke.
# Processing Record 440 of Set 1 | puerto penasco.
# Processing Record 441 of Set 1 | byron bay.
# Processing Record 442 of Set 1 | pallasovka.
# Processing Record 443 of Set 1 | ambagarh chauki.
# Processing Record 444 of Set 1 | rockland.
# Processing Record 445 of Set 1 | north bend.
# Processing Record 446 of Set 1 | pokrovskoye.
# Processing Record 447 of Set 1 | lompoc.
# Processing Record 448 of Set 1 | pando.
# Processing Record 449 of Set 1 | belle fourche.
# Processing Record 450 of Set 1 | marcona.
# City not found. Skipping...
# Processing Record 451 of Set 1 | nome.
# Processing Record 452 of Set 1 | salvador.
# Processing Record 453 of Set 1 | esmeraldas.
# Processing Record 454 of Set 1 | xinxiang.
# Processing Record 455 of Set 1 | abu dhabi.
# Processing Record 456 of Set 1 | tabou.
# Processing Record 457 of Set 1 | diego de almagro.
# Processing Record 458 of Set 1 | kavaratti.
# Processing Record 459 of Set 1 | havre-saint-pierre.
# Processing Record 460 of Set 1 | baykit.
# Processing Record 461 of Set 1 | soyo.
# Processing Record 462 of Set 1 | talcahuano.
# Processing Record 463 of Set 1 | krasnoselkup.
# Processing Record 464 of Set 1 | esperance.
# Processing Record 465 of Set 1 | mariental.
# Processing Record 466 of Set 1 | nocupetaro.
# Processing Record 467 of Set 1 | poum.
# Processing Record 468 of Set 1 | piacabucu.
# Processing Record 469 of Set 1 | east patchogue.
# Processing Record 470 of Set 1 | songkhla.
# Processing Record 471 of Set 1 | loreto.
# Processing Record 472 of Set 1 | lenoir.
# Processing Record 473 of Set 1 | verkhnevilyuysk.
# Processing Record 474 of Set 1 | nurobod.
# Processing Record 475 of Set 1 | neepawa.
# Processing Record 476 of Set 1 | vagay.
# Processing Record 477 of Set 1 | sorvag.
# City not found. Skipping...
# Processing Record 478 of Set 1 | beloha.
# Processing Record 479 of Set 1 | nizhniy kuranakh.
# Processing Record 480 of Set 1 | preobrazheniye.
# Processing Record 481 of Set 1 | northam.
# Processing Record 482 of Set 1 | lacey.
# Processing Record 483 of Set 1 | guelengdeng.
# City not found. Skipping...
# Processing Record 484 of Set 1 | seddon.
# Processing Record 485 of Set 1 | atambua.
# Processing Record 486 of Set 1 | praya.
# Processing Record 487 of Set 1 | morehead.
# Processing Record 488 of Set 1 | choma.
# Processing Record 489 of Set 1 | san carlos de bariloche.
# Processing Record 490 of Set 1 | launceston.
# Processing Record 491 of Set 1 | terrak.
# Processing Record 492 of Set 1 | batagay.
# Processing Record 493 of Set 1 | caravelas.
# Processing Record 494 of Set 1 | hazorasp.
# Processing Record 495 of Set 1 | turayf.
# Processing Record 496 of Set 1 | ngukurr.
# City not found. Skipping...
# Processing Record 497 of Set 1 | elizabeth city.
# Processing Record 498 of Set 1 | camacha.
# Processing Record 499 of Set 1 | la palma.
# Processing Record 500 of Set 1 | maceio.
# Processing Record 501 of Set 1 | pakenham.
# Processing Record 502 of Set 1 | novo aripuana.
# Processing Record 503 of Set 1 | iqaluit.
# Processing Record 504 of Set 1 | neustadt.
# Processing Record 505 of Set 1 | tamandare.
# Processing Record 506 of Set 1 | atyra.
# Processing Record 507 of Set 1 | dong xoai.
# Processing Record 508 of Set 1 | kismayo.
# Processing Record 509 of Set 1 | awbari.
# Processing Record 510 of Set 1 | boddam.
# Processing Record 511 of Set 1 | mehamn.
# Processing Record 512 of Set 1 | port macquarie.
# Processing Record 513 of Set 1 | kyabram.
# Processing Record 514 of Set 1 | salinopolis.
# Processing Record 515 of Set 1 | tautira.
# Processing Record 516 of Set 1 | awjilah.
# Processing Record 517 of Set 1 | kamloops.
# Processing Record 518 of Set 1 | sioux lookout.
# Processing Record 519 of Set 1 | mount pleasant.
# Processing Record 520 of Set 1 | delta del tigre.
# Processing Record 521 of Set 1 | dharchula.
# Processing Record 522 of Set 1 | maniitsoq.
# Processing Record 523 of Set 1 | mittagong.
# Processing Record 524 of Set 1 | tuatapere.
# Processing Record 525 of Set 1 | kirksville.
# Processing Record 526 of Set 1 | dunda.
# Processing Record 527 of Set 1 | tingo maria.
# Processing Record 528 of Set 1 | kailua.
# Processing Record 529 of Set 1 | poplar bluff.
# Processing Record 530 of Set 1 | verkhnetulomskiy.
# Processing Record 531 of Set 1 | hope.
# Processing Record 532 of Set 1 | warrnambool.
# Processing Record 533 of Set 1 | swan river.
# Processing Record 534 of Set 1 | jibuti.
# Processing Record 535 of Set 1 | zaozerne.
# Processing Record 536 of Set 1 | teguise.
# Processing Record 537 of Set 1 | abilene.
# Processing Record 538 of Set 1 | marietta.
# Processing Record 539 of Set 1 | dalbandin.
# Processing Record 540 of Set 1 | bambanglipuro.
# Processing Record 541 of Set 1 | linxi.
# Processing Record 542 of Set 1 | novochernorechenskiy.
# Processing Record 543 of Set 1 | marshfield.
# Processing Record 544 of Set 1 | aswan.
# Processing Record 545 of Set 1 | peniche.
# Processing Record 546 of Set 1 | xiaoshi.
# Processing Record 547 of Set 1 | jubayl.
# City not found. Skipping...
# Processing Record 548 of Set 1 | urumqi.
# Processing Record 549 of Set 1 | yurino.
# Processing Record 550 of Set 1 | falealupo.
# City not found. Skipping...
# Processing Record 551 of Set 1 | chuncheng.
# Processing Record 552 of Set 1 | mayo.
# Processing Record 553 of Set 1 | yulara.
# Processing Record 554 of Set 1 | krabi.
# Processing Record 555 of Set 1 | hanzhong.
# Processing Record 556 of Set 1 | obo.
# Processing Record 557 of Set 1 | male.
# Processing Record 558 of Set 1 | tromso.
# Processing Record 559 of Set 1 | viedma.
# Processing Record 560 of Set 1 | kaeo.
# Processing Record 561 of Set 1 | jodhpur.
# Processing Record 562 of Set 1 | lagoa.
# Processing Record 563 of Set 1 | tuggurt.
# City not found. Skipping...
# Processing Record 564 of Set 1 | lolua.
# City not found. Skipping...
# Processing Record 565 of Set 1 | sabirabad.
# Processing Record 566 of Set 1 | victor harbor.
# Processing Record 567 of Set 1 | nuzvid.
# Processing Record 568 of Set 1 | vanimo.
# Processing Record 569 of Set 1 | boralday.
# Processing Record 570 of Set 1 | qandala.
# Processing Record 571 of Set 1 | ulladulla.
# Processing Record 572 of Set 1 | palaikastron.
# Processing Record 573 of Set 1 | visnes.
# Processing Record 574 of Set 1 | kabwe.
# Processing Record 575 of Set 1 | zaraza.
# Processing Record 576 of Set 1 | uzumlu.
# City not found. Skipping...
# Processing Record 577 of Set 1 | abu zabad.
# Processing Record 578 of Set 1 | seoul.
# Processing Record 579 of Set 1 | motala.
# Processing Record 580 of Set 1 | sijunjung.
# Processing Record 581 of Set 1 | ofunato.
# Processing Record 582 of Set 1 | plover.
# Processing Record 583 of Set 1 | frederick.
# Processing Record 584 of Set 1 | bowen.
# Processing Record 585 of Set 1 | paris.
# Processing Record 586 of Set 1 | yumen.
# Processing Record 587 of Set 1 | ryotsu.
# Processing Record 588 of Set 1 | ha noi.
# Processing Record 589 of Set 1 | huilong.
# Processing Record 590 of Set 1 | bone.
# Processing Record 591 of Set 1 | ulaangom.
# Processing Record 592 of Set 1 | honningsvag.
# Processing Record 593 of Set 1 | payakumbuh.
# Processing Record 594 of Set 1 | aranos.
# Processing Record 595 of Set 1 | matay.
# Processing Record 596 of Set 1 | chagda.
# City not found. Skipping...
# Processing Record 597 of Set 1 | mahibadhoo.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# convert the max temp to F from Kelvin
max_temp = [(9/5)*(x - 273) + 32 for x in max_temp]

# populate the dataframe with the city info
city_df = pd.DataFrame({
                            "City":city_list,
                            "Cloudiness":cloudiness,
                            "Country":country,
                            "Date":date,
                            "Humidity":humidity,
                            "Lat":lat,
                            "Lng":lng,
                            "Max Temp":max_temp,
                            "Wind Speed":wind_speed
    
})

# write the dataframe to a csv
city_df.to_csv("world_cities.csv")
city_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0         Gamba         100      GA  1613426905        83  -2.6500   10.0000
# 1       Kavieng          46      PG  1613426905        74  -2.5744  150.7967
# 2    Bredasdorp          97      ZA  1613426905        67 -34.5322   20.0403
# 3  Longyearbyen          75      SJ  1613426905       100  78.2186   15.6401
# 4        Dayong           0      CN  1613426905        72  25.0209  118.2898
#
#    Max Temp  Wind Speed
# 0    78.926        1.14
# 1    84.218        3.76
# 2    57.470        1.03
# 3    26.870        1.03
# 4    59.270        4.00

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
#NONE

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
#N/A

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
ax.set_title('City Latitude vs. Max Temperature')
ax.scatter(city_df['Lat'],city_df['Max Temp'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_max_temp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
ax.set_title('City Latitude vs. Humidity')
ax.scatter(city_df['Lat'],city_df['Humidity'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_humidity.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
ax.set_title('City Latitude vs. Cloudiness')
ax.scatter(city_df['Lat'],city_df['Cloudiness'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_cloudiness.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
ax.set_title('City Latitude vs. Wind Speed')
ax.scatter(city_df['Lat'],city_df['Wind Speed'],edgecolors='black')
plt.grid()
fig.savefig('lat_vs_wind_speed.png')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
